# %%
import soccerdata as sd

# sofifa.com serves pages in the browser's locale, and soccerdata's parsers only
# match English labels — on this machine every attribute came back None and the
# tactic columns came back in French. SoFIFAEn forces hl=en-US. See sofifa_en.py.
from sofifa_en import SoFIFAEn

# %%
sofifa = SoFIFAEn(leagues="ENG-Premier League", versions="latest")
sofifa.versions  # `update` should read "Jul 23, 2026", not "23 juil. 2026"
# Out:
# [07/27/26 14:20:08] INFO     Saving cached data to /Users/safidyramaherison/soccerdata/data/SoFIFA   ]8;id=11236026;file:///Users/safidyramaherison/Documents/Jedha/AIFS/Projects/Final_project/Futbol/.venv/lib/python3.14/site-packages/soccerdata/_common.py\_common.py]8;;\:]8;id=11236027;file:///Users/safidyramaherison/Documents/Jedha/AIFS/Projects/Final_project/Futbol/.venv/lib/python3.14/site-packages/soccerdata/_common.py#250\250]8;;\
#            fifa_edition        update
# version_id
# 260046            FC 26  Jul 23, 2026

# %%
team_ratings = sofifa.read_team_ratings()
team_ratings.head()
# Out:
# [07/27/26 14:20:09] INFO     [1/1] Retrieving teams for ENG-Premier League in Jul 23, 2026 edition    ]8;id=11236032;file:///Users/safidyramaherison/Documents/Jedha/AIFS/Projects/Final_project/Futbol/.venv/lib/python3.14/site-packages/soccerdata/sofifa.py\sofifa.py]8;;\:]8;id=11236033;file:///Users/safidyramaherison/Documents/Jedha/AIFS/Projects/Final_project/Futbol/.venv/lib/python3.14/site-packages/soccerdata/sofifa.py#341\341]8;;\
#                                           overall attack midfield defence  \
# league             team
# ENG-Premier League AFC Bournemouth             78     79       78      77
#                    Arsenal                     84     86       85      84
#                    Aston Villa                 81     82       81      80
#                    Brentford                   78     81       78      77
#                    Brighton & Hove Albion      78     80       79      78
#
# ...

# %%
player_ratings = sofifa.read_player_ratings(team="Arsenal")
player_ratings.head()
# Out:
#                     INFO     [1/1] Retrieving teams for ENG-Premier League in Jul 23, 2026 edition    ]8;id=11236038;file:///Users/safidyramaherison/Documents/Jedha/AIFS/Projects/Final_project/Futbol/.venv/lib/python3.14/site-packages/soccerdata/sofifa.py\sofifa.py]8;;\:]8;id=11236039;file:///Users/safidyramaherison/Documents/Jedha/AIFS/Projects/Final_project/Futbol/.venv/lib/python3.14/site-packages/soccerdata/sofifa.py#188\188]8;;\
#                     INFO     [1/1] Retrieving list of players for Arsenal in Jul 23, 2026 edition     ]8;id=11236044;file:///Users/safidyramaherison/Documents/Jedha/AIFS/Projects/Final_project/Futbol/.venv/lib/python3.14/site-packages/soccerdata/sofifa.py\sofifa.py]8;;\:]8;id=11236045;file:///Users/safidyramaherison/Documents/Jedha/AIFS/Projects/Final_project/Futbol/.venv/lib/python3.14/site-packages/soccerdata/sofifa.py#259\259]8;;\
# ...
